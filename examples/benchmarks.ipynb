# %%
from utils.plotting import *
import warnings

warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# Global flag to control figure saving
save_fig = False

# %% [markdown]
# ## Projection benchmarks

# %%
proj_results = load_proj_results("proj.pkl")
plot_proj_benchmarks(proj_results, save_figures=save_fig)
display_benchmark_tables(proj_results, proj_config)
# Out:
# Benchmark Results ($\tau$ = 0.5)
# <style type="text/css">
# #T_dd9ed th {
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #666;
# }
# #T_dd9ed td {
#   border: 1px solid #666;
# }
# ...

# %% [markdown]
# ## CVQP benchmarks

# %% [markdown]
# ### Portfolio optimization

# %%
portfolio_results = load_cvqp_results('portfolio')
plot_cvqp_benchmarks(portfolio_results, save_figures=save_fig)
display_benchmark_tables(portfolio_results, cvqp_config)
# Out:
# Benchmark Results (n_vars = 2000)
# <style type="text/css">
# #T_643bf th {
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #666;
# }
# #T_643bf td {
#   border: 1px solid #666;
# }
# ...

# %% [markdown]
# ### Quantile regression

# %%
quantile_results = load_cvqp_results('quantile_regression')
plot_cvqp_benchmarks(quantile_results, save_figures=save_fig)
display_benchmark_tables(quantile_results, cvqp_config)
# Out:
# Benchmark Results (n_vars = 500)
# <style type="text/css">
# #T_1b4fb th {
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #666;
# }
# #T_1b4fb td {
#   border: 1px solid #666;
# }
# ...
