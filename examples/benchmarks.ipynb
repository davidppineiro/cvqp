# %%
from plot_util import *
import warnings

warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# Global flag to control figure saving
save_fig = False

# %% [markdown]
# ## Projection benchmarks

# %%
proj_results = load_results("proj.pkl", flatten=True)
plot_proj_benchmarks(proj_results, save_figures=save_fig)
# Out:
# {0.5: <Figure size 600x450 with 1 Axes>}

# %% [markdown]
# ## CVQP benchmarks

# %% [markdown]
# ### Portfolio optimization

# %%
portfolio_results = load_results("portfolio.pkl")
plot_cvqp_benchmarks(portfolio_results, save_figures=save_fig)
# Out:
# {2000: <Figure size 600x450 with 1 Axes>}

# %% [markdown]
# ### Quantile regression

# %%
quantile_results = load_results("quantile_regression.pkl")
plot_cvqp_benchmarks(quantile_results, save_figures=save_fig)
# Out:
# {500: <Figure size 600x450 with 1 Axes>}
